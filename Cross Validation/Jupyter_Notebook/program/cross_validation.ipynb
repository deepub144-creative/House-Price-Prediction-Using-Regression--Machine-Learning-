# %%
# FAST CROSS VALIDATION 
import pandas as pd
import numpy as np

from sklearn.model_selection import cross_val_score, KFold
from sklearn.ensemble import RandomForestRegressor

# Load data
df = pd.read_csv("C:/Users/deepu/Downloads/featured_housing.csv")

X = df.drop("median_house_value", axis=1)
y = df["median_house_value"]


model = RandomForestRegressor(
    n_estimators=50,   
    max_depth=10,      
    n_jobs=-1,
    random_state=42
)

# FAST CV
kfold = KFold(n_splits=2, shuffle=True, random_state=42)

# Run CV
r2_scores = cross_val_score(model, X, y, cv=kfold, scoring='r2', n_jobs=-1)

print("\nFAST CROSS VALIDATION RESULTS")
print("--------------------------------")
print("R2 Scores:", r2_scores)
print("Mean R2:", np.mean(r2_scores))
# Out:
# FAST CROSS VALIDATION RESULTS
# --------------------------------
# R2 Scores: [0.77682704 0.78639755]
# Mean R2: 0.7816122960039897
